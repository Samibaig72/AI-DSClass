# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
time = [0, 1, 2, 3, 4]
revenue = [200, 400, 650, 800, 850]
costs = [150, 500, 550, 550, 560]

# %%
plt.plot(revenue,time)
plt.plot(costs, time)
plt.show()

# %%
plt.plot(time, revenue, color='purple', linestyle='--')
plt.plot(time, costs, color='#82edc9', marker='o')

# %%
plt.plot(time, costs, color=(1,0,0,0.5), marker='D' ,alpha=0.2)

# %%
x = [0, 1, 2, 3, 5]
y = [0, 1, 4, 9, 11]
plt.plot(x, y)
plt.axis([0, 3, 2, 5])
plt.show()

# %%
months = range(12)
temperature = [36, 36, 39, 52, 61, 72, 77, 75, 68, 57, 48, 48]
flights_to_hawaii = [1200, 1300, 1100, 1450, 850, 750, 400, 450, 400, 860, 990, 1000]


plt.suptitle("Practice")

plt.subplot(1, 2, 1)
plt.ylabel("Temp")
plt.subplots_adjust(wspace = .5)
plt.plot(months, temperature)



plt.subplot(1, 2, 2)
plt.ylabel("Temp2")
plt.plot(flights_to_hawaii,temperature)
